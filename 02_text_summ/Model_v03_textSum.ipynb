# %%
# !pip install bert-extractive-summarizer;

# %%
# !pip install -U spacy
# !pip install transformers # > 4.0.0
# !pip install neuralcoref

# !python -m spacy download en_core_web_md

# %%
import pandas as pd
import numpy as np
import re
from summarizer import Summarizer;

# %%
from google.colab import drive 
drive.mount('/content/drive/')

import os
os.chdir("/content/drive/MyDrive/yelp_austin")
# !ls
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# attributes_cat_as_columns.csv  austin_review.csv  logs
# austin_checkin.csv	       austin_tip.csv	  pytorchversion.pkl
# austin_rest.csv		       austin_user.csv	  results

# %%
rev_df = pd.read_csv('austin_review.csv')

# %%
one_rest_df = rev_df[rev_df.business_id == "MGzro82Fi4LYvc86acoONQ"]

# %%
good = one_rest_df[one_rest_df.stars >= 4.0].sample(min(100, one_rest_df[one_rest_df.stars >= 4.0].shape[0]))
bad = one_rest_df[one_rest_df.stars <= 3.0].sample(min(100, one_rest_df[one_rest_df.stars <= 3.0].shape[0]))

# %%
goodRev = good.text.str.cat(sep=" ")

# %%
model = Summarizer();
# Out:
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.25G [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
result = model(goodRev, num_sentences=10)
full = ''.join(result)

# %%
print(full)
# Out:
# PRE-ORDER your meat on their website; that's the trick! The bourbon-banana pie was also really good and you can really taste the bourbon down in the center, but not "the-second-coming status" my friend claims with some alcohol-permeated desserts he's had at Humphry Slocombe (eg, secret breakfast). I've had BBQ from a few different joints in ATX so I was a little skeptical about how good Franklin could be but after trying it... damn, I'd stand in this line over and over again. How can it be better than places that have been doing it right for 50 years. I don't know how, but the president of the Austin Facial Hair Club managed to reserve Franklin Barbecue for dinner. I have also tried the turkey which is good, but turkey is not my thing. So after very nearly an hour and 20 minutes of standing in the line that runs from outside into and around the periphery of the dining room, taking you past framed articles from local papers, state magazines, and even Bon Appetit (who named Franklin's 
# ...
