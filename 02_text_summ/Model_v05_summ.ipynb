# %%
# !pip install bert-extractive-summarizer;

# !pip install -U spacy
# !pip install transformers # > 4.0.0
# !pip install neuralcoref

# !python -m spacy download en_core_web_md

import pandas as pd
import numpy as np
import re
from summarizer import Summarizer;

# %%
model = Summarizer();
# Out:
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.25G [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
from google.colab import drive 
drive.mount('/content/drive/')

import os
os.chdir("/content/drive/MyDrive/yelp_austin")
# !ls
# Out:
# Mounted at /content/drive/
# attributes_cat_as_columns.csv  logs
# austin_checkin.csv	       pytorchversion.pkl
# austin_rest.csv		       rest_with_good_bad_review.csv
# austin_review.csv	       results
# austin_tip.csv		       words_filtered_rev.csv
# austin_user.csv

# %%
bus_df = pd.read_csv('rest_with_good_bad_review.csv')

# %%
bus_df = bus_df.loc[(bus_df['good_reviews'].notna()) & (bus_df['bad_reviews'].notna())]

# %%
result = model(bus_df.bad_reviews[4], num_sentences=10)
print(result)
# Out:
# The atmosphere is "pasty" and we were the only one's in the place. I'm not sure why we didn't go to Hai Ky but now we know. The food was very average, no zing, no WOW that was good, nada. Not sure who came up with the "Big 3" thing on Oltorf...but the other 2 are far superior to this one. They cant work up any enthusiasm to serve their pho, and I cant work up any enthusiasm to eat here. The pho tastes just as it should, service is quick (we usually get take out), and it's easy to get in and out. I guess I'm going to have to try the other Vietnamese places on Oltorf. I had the Bahn Mi pork sandwich and an egg roll. Pork was burnt and the egg roll came out cold. I know your suppose to order the Pho but I read the sandwiches were awesome. Look forward to trying some other dishes.
