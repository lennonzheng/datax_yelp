# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive 
drive.mount('/content/drive/')

import os
os.chdir("/content/drive/MyDrive/datax/merging")
# !ls
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# attribute_analysis_output.xlsx	attribute_analysis_v2.xlsx  Merge_01.ipynb

# %%
att = pd.read_excel("attribute_analysis_v2.xlsx")

# %%
att.head()
# Out:
#               business_id  ...           Attributes with Positive effect on stars
# 0  Xw8tuI30T-xihpzwBV-zJg  ...  1. The restaurant has a good food menu.\n2. Th...
# 1  e4aCvCERYCMjGXSiMwcwPA  ...  1. The restaurant has a good food menu.\n2. Th...
# 2  ZjExuvrL3CUicY2F9xhzSA  ...  1. The restaurant has a good food menu.\n2. Th...
# 3  JpuCKMWJSFPnOu-GK46-cA  ...  1. The restaurant has a good food menu.\n2. Th...
# 4  iyT4BjWxS3ITVSjg2M56ZA  ...  1. The restaurant has a good food menu.\n2. Th...
#
# [5 rows x 14 columns]

# %%
att.shape
# Out:
# (4956, 14)

# %%
att = att[["business_id", "Attributes with Negative effect on stars", "Attributes with Positive effect on stars"]]

# %%
att.head()
# Out:
#               business_id  ...           Attributes with Positive effect on stars
# 0  Xw8tuI30T-xihpzwBV-zJg  ...  1. The restaurant has a good food menu.\n2. Th...
# 1  e4aCvCERYCMjGXSiMwcwPA  ...  1. The restaurant has a good food menu.\n2. Th...
# 2  ZjExuvrL3CUicY2F9xhzSA  ...  1. The restaurant has a good food menu.\n2. Th...
# 3  JpuCKMWJSFPnOu-GK46-cA  ...  1. The restaurant has a good food menu.\n2. Th...
# 4  iyT4BjWxS3ITVSjg2M56ZA  ...  1. The restaurant has a good food menu.\n2. Th...
#
# [5 rows x 3 columns]

# %%
# att = att.rename({"FeaturesDescr 1+": "attribute_1_pos", 
#             "FeaturesDescr 1-": "attribute_1_neg", 
#             "FeaturesDescr 2+": "attribute_2_pos",
#             "FeaturesDescr 2-": "attribute_2_neg",
#             "FeaturesDescr 3+": "attribute_3_pos",
#             "FeaturesDescr 3-": "attribute_3_neg",
#             "FeaturesDescr 4+": "attribute_4_pos",
#             "FeaturesDescr 4-": "attribute_4_neg",
#             "FeaturesDescr 5+": "attribute_5_pos",
#             "FeaturesDescr 5-": "attribute_5_neg",
#             }, axis=1)

# %%
os.chdir("/content/drive/MyDrive/datax/summarizer")
# !ls
# Out:
# Model_08_TextSum.ipynb	rest_w_summarizer_and_zero_shot_results.csv
# Model_v05_summ.ipynb	sum_review_bus_02.csv

# %%
rest = pd.read_csv("rest_w_summarizer_and_zero_shot_results.csv")

# %%
rest.head()
# Out:
#               business_id  ...                                            bad_sum
# 0  NRPemqVb4qpWFF0Avq_6OQ  ...  I've had very cheap to very expensive sushi in...
# 1  bRsDZ44CD3uhGnRY3NeQhQ  ...  i. come and i have been here (sadly) about 20x...
# 2  Pk4ZwXwUU50BDn5gqw_rKg  ...  We came here for dinner b/c we thought we knew...
# 3  IFB2K3BEZ2L_Mv5AbUD26Q  ...  Server was friendly, just no utensils for a wh...
# 4  fBvQQUk1-V9IUA8PbuYFWg  ...  The food is pretty good, with quite a bit of f...
#
# [5 rows x 21 columns]

# %%
combined = rest.merge(att, how="inner", on="business_id")

# %%
combined = combined.rename({"Attributes with Negative effect on stars": "attributes_w_neg_effect_on_stars", 
                            "Attributes with Positive effect on stars": "attributes_w_pos_effect_on_stars",
                            }, axis=1)

# %%
combined.head()
# Out:
#               business_id  ...                   attributes_w_pos_effect_on_stars
# 0  NRPemqVb4qpWFF0Avq_6OQ  ...  1. The restaurant is wheelchair accessible.\n2...
# 1  bRsDZ44CD3uhGnRY3NeQhQ  ...  1. The restaurant has bike parking.\n2. The re...
# 2  Pk4ZwXwUU50BDn5gqw_rKg  ...  1. The restaurant accepts reservations.\n2. Th...
# 3  IFB2K3BEZ2L_Mv5AbUD26Q  ...  1. The restaurant allows dogs.\n2. The restaur...
# 4  fBvQQUk1-V9IUA8PbuYFWg  ...  1. The restaurant is wheelchair accessible.\n2...
#
# [5 rows x 23 columns]

# %%
combined.to_csv("toFrontend_v01.csv", index=False)
